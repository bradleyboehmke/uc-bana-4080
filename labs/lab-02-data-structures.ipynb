# %% [markdown]
# # Week 2 Lab: Python Data Science Ecosystem
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bradleyboehmke/uc-bana-4080/blob/main/labs/lab-02-data-structures.ipynb)
#
# Data analysts spend much of their time documenting work, organizing information, and leveraging libraries to solve problems efficiently. This lab gives you hands-on practice with the three pillars of the Python data science environment: Jupyter notebooks for professional documentation, built-in data structures for organizing business data, and Python libraries that multiply your analytical capabilities.
#
# ## Learning Objectives
#
# By the end of this lab, you will be able to:
#
# - Use Jupyter notebook features effectively for professional, reproducible data work
# - Choose and apply the right data structure (list, tuple, dictionary) for a given business problem
# - Import and use modules from Python's standard library for real-world calculations
# - Load and begin exploring the `completejourney_py` package used in this course's midterm project
#
# ## Lab Structure
#
# **Total time:** 75 minutes | **Format:** Small groups (2–4 students)
#
# | Segment | Duration |
# |---------|---------|
# | Part A: Guided Reinforcement | ~30 min |
# | Class Q&A & Transition | ~5–10 min |
# | Part B: Independent Challenges | ~35–40 min |
# | Wrap-up & Reflection | ~3–5 min |
#
# ## This Lab Reinforces
#
# - [**Chapter 4: Getting Started with Jupyter Notebooks**](https://bradleyboehmke.github.io/uc-bana-4080/book/04-jupyter.html)
# - [**Chapter 5: Introduction to Data Structures**](https://bradleyboehmke.github.io/uc-bana-4080/book/05-data-structures.html)
# - [**Chapter 6: Packages, Libraries, and Modules**](https://bradleyboehmke.github.io/uc-bana-4080/book/06-libraries.html)

# %% [markdown]
# ## Setup

# %%
import datetime
import random
import numpy as np
import pandas as pd

# %% [markdown]
# ---
#
# ## Part A — Guided Reinforcement (~30 min)
#
# Work through each section with your group. The TA will walk through the demo code, then give you time to complete the "Your Turn" exercises.

# %% [markdown]
# ### A1: Jupyter Notebooks as Professional Tools (~8 min)
#
# A Jupyter notebook isn't just a code runner — it's a **communication tool**. Analysts use notebooks to document methodology, present findings to stakeholders, and create reproducible workflows that others can inspect and trust.
#
# The key to professional notebooks is the **three-cell pattern** — use it for every analysis step:
#
# - **Markdown before the code** — explain the *why*: what question are you answering, what data are you working with, and what approach will you take?
# - **Code cell** — compute the result with well-named variables and formatted output
# - **Markdown after the code** — interpret the result in business terms: what does the number mean, and what action does it inform?
#
# > **Problem → Approach → Code → Interpretation**
#
# In Tuesday's lecture you saw two example notebooks that demonstrate this pattern:
# - **[Example Analysis Notebook](https://github.com/bradleyboehmke/uc-bana-4080/blob/main/notebooks/examples/example_notebook.ipynb)** — a full business analysis with context, methodology, and findings
# - **[Example Homework Notebook](https://github.com/bradleyboehmke/uc-bana-4080/blob/main/notebooks/examples/example_homework_notebook.ipynb)** — a well-structured assignment with problem, approach, and answer
#
# Here is the same calculation two ways:
#
# ❌ **Undocumented** (correct answer, no story):
# ```python
# print(1240 * 79.99 * (1 - 0.04))
# ```
#
# ✅ **Documented** — three-cell pattern:
#
# *[Markdown before]* **Q4 Net Revenue — Wireless Headphones.** We have 1,240 units ordered at \$79.99 list price. Finance applies a 4% return allowance before revenue is recognized. Goal: confirm we met the $95K quarterly target.
#
# ```python
# units_sold, unit_price, return_rate = 1_240, 79.99, 0.04
# net_revenue = units_sold * unit_price * (1 - return_rate)
# print(f"Net revenue: ${net_revenue:,.2f}")
# ```
#
# *[Markdown after]* Net revenue of \$95,067.84 exceeds the \$95K plan — we're on target. The 4% return rate is below the 5% alert threshold, so no corrective action is needed.
#
# The **code cell** carries the computation. The **markdown cells** carry the reasoning and the story.

# %% [markdown]
# 🧠 **Your Turn**
#
# **Scenario:** Your company sells premium coffee subscriptions. This quarter, customers chose from three plans:
#
# | Plan | Monthly price | Subscribers this quarter |
# |------|--------------|--------------------------|
# | 3-month | \$45.99 | 1,240 |
# | 6-month | \$39.99 | 875 |
# | 12-month | \$34.99 | 420 |
#
# **Task:** Calculate the total revenue generated by each plan and the combined quarterly total. Note that this quarter's goal was \$100,000 in revenue and next quarter's goal is 20% growth ($120,000). Print a clean summary.
#
# Follow the **three-cell pattern**:
#
# 1. **Before your code** — add a markdown cell with a brief title and 1–2 sentences explaining what you're calculating and why this breakdown matters to the business
# 2. **Write your code** in the cell below using descriptive variable names and f-string output
# 3. **After your code** — fill in the interpretation cell below

# %%
# Your code here

# %% [markdown]
# *✍️ **Interpretation:** What does the revenue split tell you about customer plan preferences? Which plan drives the most revenue, and what might that suggest for future pricing decisions?*

# %% [markdown]
# ### 📌 Reminder: The Three-Cell Pattern
#
# Look at what you just did in A1 — that is exactly the structure expected in **every homework and project submission** this semester:
#
#  1. **Markdown before** — state the business question, the data you're working with, and your approach
#  2. **Code cell** — clean, readable code with descriptive variable names
#  3. **Markdown after** — interpret the result in plain English: what does the number *mean*, and what would you *do* with it?
#
#  This sounds simple, but it's the most common gap in student work. A notebook full of code cells that produce numbers — with no explanation of *why* or *so what* — is not an analysis. It's a calculation.
#
#  **A manager reading your notebook should be able to follow your reasoning without running a single line of code.**
#
#  ✅ Before you submit anything this semester, ask yourself: *Could someone who didn't write this code understand what I did and why it matters?* If not, add the markdown.

# %% [markdown]
# ### A2: Basic Data Structures in Python (~12 min)
#
# Choosing the right data structure is a foundational skill. Each structure has a specific purpose:
#
# | Structure | Ordered | Mutable | Best for |
# |-----------|---------|---------|----------|
# | `list` | ✓ | ✓ | Sequences that may grow, shrink, or change over time |
# | `tuple` | ✓ | ✗ | Fixed groupings that should never be modified |
# | `dict` | ✓* | ✓ | Labeled data where you access values by name, not position |
#
# *Insertion order preserved in Python 3.7+
#
# The demos below walk through each structure in a retail context. For each one, pay attention to: (1) when you would choose it, and (2) what operations it supports.

# %% [markdown]
# **Lists** — ordered, mutable sequences. Use when values may change over time: daily figures that need corrections, incoming records, or results you're building incrementally.

# %%
# LIST: ordered and mutable — append new data, update corrections, then summarize
weekly_sales = [4250.50, 3890.25, 5120.75, 4600.00, 6340.80]

weekly_sales.append(5890.00)  # Friday's figures arrived late — add to end
weekly_sales[0] = 4275.00     # Monday's figure was corrected — update in place

print("Weekly Sales")
print(f"  Days recorded: {len(weekly_sales)}")
print(f"  Total:   ${sum(weekly_sales):,.2f}")
print(f"  Best:    ${max(weekly_sales):,.2f}")
print(f"  Worst:   ${min(weekly_sales):,.2f}")

# %% [markdown]
# **Tuples** — ordered, immutable groupings. Use for facts that are fixed by nature: GPS coordinates, record identifiers, or constant configuration values. Immutability is a feature — it signals to future readers (and to Python) that this value should never change.

# %%
# TUPLE: ordered and immutable — coordinates are a geographic fact, not a variable
store_location = (39.1031, -84.5120)   # (latitude, longitude) for Cincinnati HQ

lat, lon = store_location   # tuple unpacking — assign each element to its own name
print(f"Store HQ: {lat}°N, {lon}°W")

# Tuples enforce immutability — this line would raise a TypeError:
# store_location[0] = 41.0   # ← uncomment to see the error

# %% [markdown]
# **Dictionaries** — mutable key-value pairs. Use when data has meaningful labels and you need to access or update individual fields by name, not by position. Any "row" of named attributes — a product record, a customer profile, a store summary — maps naturally to a dictionary.

# %%
# DICT: labeled key-value pairs — access and update by name, not by index
product = {
    "name": "Wireless Headphones",
    "sku": "WH-2024",
    "price": 79.99,
    "in_stock": 142
}

print(f"Product: {product['name']}  |  SKU: {product['sku']}")
print(f"Price: ${product['price']}  |  Stock: {product['in_stock']} units")

product["price"] = 69.99        # update an existing field in place
product["on_clearance"] = True  # add a new field — dicts are flexible

print(f"\nUpdated: ${product['price']}  |  Clearance: {product['on_clearance']}")

# %%
# DICT: nested structures — a product catalog with multiple entries and mixed data types
catalog = {
    "WH-2024": {
        "name": "Wireless Headphones",
        "price": 79.99,
        "in_stock": 142,
        "tags": ["electronics", "audio", "wireless"],      # list nested in dict
        "dimensions": (7.5, 6.2, 3.1)                      # tuple nested in dict
    },
    "BT-2024": {
        "name": "Bluetooth Speaker",
        "price": 49.99,
        "in_stock": 87,
        "tags": ["electronics", "audio", "portable"],
        "dimensions": (4.0, 4.0, 3.5)
    },
    "SW-2024": {
        "name": "Smart Watch",
        "price": 199.99,
        "in_stock": 34,
        "tags": ["electronics", "wearables"],
        "dimensions": (1.7, 1.5, 0.4)
    }
}

# Access a top-level value
print(f"Number of products in catalog: {len(catalog)}")

# Access a nested value — two bracket lookups: catalog[sku][field]
print(f"\nSmart Watch price: ${catalog['SW-2024']['price']}")

# Access a value nested inside a list inside a dict
print(f"First tag for BT Speaker: {catalog['BT-2024']['tags'][0]}")

# Access a value nested inside a tuple inside a dict
height = catalog['WH-2024']['dimensions'][2]
print(f"Headphone height: {height} in")

# %% [markdown]
# 🧠 **Your Turn**
#
# **Scenario:** You are a data scientist supporting a regional retail district. You have three different data needs, and for each one you need to choose the right Python data structure.
#
# - **Scenario 1 — Store roster:** The district currently has four stores: STR-001, STR-002, STR-003, STR-004. New stores may be added as the district expands. You will look stores up by position and add new ones over time.
#
# - **Scenario 2 — District headquarters:** The district HQ is located at latitude 39.1031, longitude -84.5120 (Cincinnati, OH). This is a fixed geographic fact used in logistics reports — it should never change.
#
# - **Scenario 3 — Top store profile:** STR-001 in Cincinnati is the district's highest-selling store. Build a profile for this store that includes:
#   - Store identifier: STR-001
#   - Location: latitude 39.1031, longitude -84.5120
#   - Store manager: John Doe
#   - Monthly revenue for the last five months:
#
#     | Month | Revenue |
#     |-------|---------|
#     | January | $132,500 |
#     | February | $118,300 |
#     | March | $145,800 |
#     | April | $139,200 |
#     | May | $151,700 |
#
#   This profile feeds the district's regional performance report, and the revenue list needs to grow each month as new data arrives.
#
# **Tasks:**
# 1. Create a data structure for each of the three scenarios above. For the store profile, think carefully about how to store the location and the revenue history *inside* the dictionary.
# 2. Using tuple unpacking, assign the district HQ latitude and longitude to separate variables and print them with an f-string.
# 3. June revenue just came in at $147,200 — add it to the monthly revenue list inside the store profile dictionary.
# 4. Compute and print the total revenue across all six months using the list stored in the store profile.
#
# **Before your code**, add a markdown cell that states which structure you chose for each scenario and justifies *why* that structure is the right fit — including how you stored the location and revenue history within the store profile dictionary.
#
# After running your code, fill in the interpretation cell below.

# %%
# Your code here

# %% [markdown]
# *✍️ **Interpretation:** Did you find it natural to embed a list inside the dictionary? What does the 6-month revenue total tell you about this store's performance — and what other fields might you add to this profile in a real-world context?*

# %% [markdown]
# ### A3: Importing and Using Libraries (~10 min)
#
# Python's library ecosystem is organized in two tiers:
#
# - **Standard library** — ships with every Python installation; no install required (`datetime`, `random`, `math`, `os`)
# - **Third-party libraries** — installed separately via `pip`; power the data science ecosystem (`numpy`, `pandas`, `seaborn`, `scikit-learn`)
#
# The demos below work through both tiers. The standard library handles everyday tasks out of the box; third-party packages extend Python into specialized domains that would be impractical to build from scratch.

# %% [markdown]
# **Standard Library: `datetime`** — date arithmetic for business calendars, deadlines, and time-based reporting. No install needed — it ships with Python.

# %%
import datetime

today = datetime.date.today()
fiscal_year_end = datetime.date(today.year, 12, 31)
days_remaining = (fiscal_year_end - today).days

print(f"Today:                         {today}")
print(f"Fiscal year end:               {fiscal_year_end}")
print(f"Days remaining in fiscal year: {days_remaining}")

# %% [markdown]
# **Standard Library: `random`** — generate random values for simulations, sampling, and scenario modeling. Also ships with Python.

# %%
import random

# Simulate promotional discount offers for three loyalty program customers
offer_a = random.randint(5, 25)
offer_b = random.randint(5, 25)
offer_c = random.randint(5, 25)

offers = [offer_a, offer_b, offer_c]
print(f"Discount offers generated: {offers}%")
print(f"Average discount offered:  {sum(offers) / len(offers):.1f}%")

# %% [markdown]
# **Third-Party Libraries** — installed via `pip`, these extend Python into specialized domains you couldn't build yourself without enormous effort. You'll use several throughout this course:
#
# | Library | Purpose | When you'll use it |
# |---------|---------|-------------------|
# | `numpy` | Fast numerical arrays, vectorized math | Throughout the course |
# | `pandas` | DataFrames and data manipulation | Module 3 |
# | `matplotlib` / `seaborn` | Data visualization | Module 5 |
# | `scikit-learn` | Machine learning | Module 8 |
#
# All are already installed in this environment — just import them.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

print(f"NumPy version:   {np.__version__}")
print(f"Pandas version:  {pd.__version__}")
print(f"Seaborn version: {sns.__version__}")

# A quick taste of pandas — you'll go deep on DataFrames in Module 3
preview = pd.DataFrame({
    "plan":     ["3-month", "6-month", "12-month"],
    "price":    [45.99, 39.99, 34.99],
    "subscribers": [1240, 875, 420]
})
print("\nSubscription plans table:")
print(preview)

# %% [markdown]
# **NumPy** — the backbone of numerical computing in Python. Its defining feature is **vectorized math**: operations apply to every element of an array simultaneously, without a loop.

# %%
import numpy as np

sales_array = np.array([4250.50, 3890.25, 5120.75, 4600.00, 6340.80])

projected = sales_array * 1.10   # 10% growth applied to all elements at once

print(f"Actual sales:     {sales_array}")
print(f"Projected (+10%): {projected.round(2)}")
print(f"Mean:  ${np.mean(sales_array):,.2f}")
print(f"Stdev: ${np.std(sales_array):,.2f}")
print(f"Total: ${np.sum(sales_array):,.2f}")

# %% [markdown]
# 🧠 **Your Turn**
#
# **Scenario:** Your company launched a 12-week promotional campaign starting today. You want to know when it ends and get a rough sense of expected daily attendance.
#
# **Task:**
# 1. Use `datetime` to calculate and print the campaign end date — add 84 days to today using `datetime.timedelta(days=84)`
# 2. Use `random.randint` to simulate three daily attendance figures between 200 and 500. Assign each to its own variable, then store all three in a list.
# 3. Convert your list to a NumPy array and print the mean, total, and maximum attendance across those three days
#
# **Follow the three-cell pattern:**
# - **Before your code** — describe the campaign and what you're calculating in 1–2 sentences
# - **After your code** — fill in the interpretation cell below

# %%
# Your code here

# %% [markdown]
# *✍️ **Interpretation:** When does the campaign end? What do the simulated attendance figures suggest, and how much should you trust the estimate given the numbers are random?*

# %% [markdown]
# ### ✅ Check Your Understanding
#
# Discuss with your group:
#
# 1. In A2 you used a tuple for store coordinates. What would go wrong — practically or conceptually — if you used a list instead?
# 2. The `weekly_sales.append(5890.00)` call modifies the list in place without returning a new list. When could this "mutates in place" behavior cause a hard-to-find bug?
# 3. NumPy applies math to every element of an array at once. What type does `np.array([1, 2, 3])` produce, and how is it different from the plain Python list `[1, 2, 3]`? Try `type(np.array([1, 2, 3]))` vs `type([1, 2, 3])` in a new code cell to confirm.

# %% [markdown]
# ---
#
# ## Class Q&A & Transition (~5–10 min)
#
# Compare your Part A results with another group:
#
# - Did your A1 revenue calculations match? What variable names did you choose, and why?
# - How did your groups structure the top store dictionary differently in A2 — did anyone add fields others didn't think of?
# - Any questions before independent work begins?

# %% [markdown]
# ---
#
# ## Part B — Independent Challenges (~35–40 min)
#
# For each challenge below:
#
# - **Start from a blank cell** — minimal starter code is provided
# - **Do not use AI** to generate code; work with your group to try write it from scratch first. If you're stumped then Google or AI it but be sure to understand what the code is doing!
# - **Follow the documentation pattern** — add a markdown cell before your code stating your approach, and fill in the interpretation cell after running it
# - **Ask your instructor** if you're stuck after 3–5 minutes
# - We'll debrief each challenge as a class when time is called

# %% [markdown]
# ### Challenge 1 — Sales Performance Summary
#
# **Business question:** A retail store needs a 10-day sales summary for a regional manager's report.
#
# **Setup:** Use the starting code below to generate 10 daily sales figures.
#
# Then calculate and print: total revenue, daily average, the highest-grossing day and its day number (Day 1 = first element), and the count of days that exceeded the daily average.  This may take some Googling or AI to help you determine the best approach.  That's ok but be sure you understand the code being used!
#
# **Note:** Setting `random.seed(42)` before any `randint` calls ensures everyone in the class produces identical data.
#
# **Document your work:** Add a markdown cell before your code explaining your approach. After running it, fill in the interpretation cell below.

# %%
# Your code here
random.seed(42)  # for reproducibility
daily_sales = random.sample(range(3000, 8500), 10)  # generate 10 daily sales figures between $3,000 and $8,500

# %% [markdown]
# *✍️ **Interpretation:** What story do these numbers tell? Is the store's performance strong, and which metric do you think is most actionable for a manager?*

# %% [markdown]
# ### Challenge 2 — Product Catalog Lookup
#
# **Business question:** Your merchandising team provided the following product data:
#
# | Product ID | Name | Category | Price | Stock |
# |-----------|------|----------|-------|-------|
# | `"WH-001"` | Wireless Headphones | Electronics | \$79.99 | 142 units |
# | `"BT-002"` | Bluetooth Speaker | Electronics | \$49.99 | 87 units |
# | `"SW-003"` | Smart Watch | Wearables | \$199.99 | 34 units |
#
# **Task:** Store this catalog as a dictionary of nested dictionaries keyed by product ID. Then, for the Smart Watch: (1) look it up by product ID and print its name and current price, (2) calculate and print what its price would be after a 15% promotional discount, and (3) calculate and print the total inventory value (price × stock) for that product.
#
# **Hint:** Access a nested value with two bracket lookups: `catalog["SW-003"]["price"]`.
#
# **Document your work:** Add a markdown cell before your code explaining your approach. After running it, fill in the interpretation cell below.

# %%
# Your code here

# %% [markdown]
# *✍️ **Interpretation:** What is the Smart Watch's full-price inventory value? After the 15% discount, is the reduced price likely to move the 34 units in stock — and would the promotion be worth running?*

# %% [markdown]
# ### Challenge 3 — Fiscal Deadline Tracker
#
# **Business question:** Your company has three upcoming deadlines: Q1 close (March 31), mid-year review (June 30), and fiscal year end (December 31) — all in the current year. For each deadline, print how many days away it is and what day of the week it falls on. Then identify which deadline is coming up soonest.
#
# **Hint:** `datetime.date` objects support subtraction to get a `timedelta`; `.strftime('%A')` returns the full day name.
#
# **Document your work:** Add a markdown cell before your code explaining your approach. After running it, fill in the interpretation cell below.

# %%
# Your code here

# %% [markdown]
# *✍️ **Interpretation:** Which deadline is soonest, and what does the day-of-week tell you about scheduling any prep work?*

# %% [markdown]
# ### Challenge 4 — First Look at the Course Dataset
#
# The `completejourney_py` package contains real retail transaction data from a consumer goods company — this is the dataset you'll use for the midterm project. Start by visiting the **[package documentation](https://cunningjames.github.io/completejourney_py/)** to get oriented before you write any code.
#
# **Task:**
#
# 1. Install and import `completejourney_py`, call `cj.get_data()`, and use `type()` to print what kind of object it returns.
# 2. Print the keys of the returned object to see which datasets are available.
# 3. Navigate to the [package documentation](https://cunningjames.github.io/completejourney_py/) and read the dataset descriptions. In the **interpretation cell below**, summarize what each dataset contains and what business questions you could answer by combining them.
#
# **Hint:** Install with `!pip install completejourney_py`, then:
# ```python
# import completejourney_py as cj
# data = cj.get_data()
# ```
#
# **Document your work:** Add a markdown cell before your code with your approach. Use the interpretation cell for your documentation summary from the package docs.

# %%
# Your code here

# %% [markdown]
# *✍️ **Interpretation:** List the datasets available in `completejourney_py`. Based on the docs, what does each one contain? What business questions could you answer by joining two or more of them together?*

# %% [markdown]
# ---
#
# ## (Optional) Extension
#
# If your group finishes early:
#
# What other business questions could you answer with the `completejourney_py` data? Review the [dataset overview](https://cunningjames.github.io/completejourney_py/user-guide/datasets/) along with the various cookbooks (i.e. [top 10 best selling products](https://cunningjames.github.io/completejourney_py/cookbook/top-products/), [shopping frequency analysis](https://cunningjames.github.io/completejourney_py/cookbook/shopping-frequency/), [market basket analysis](https://cunningjames.github.io/completejourney_py/cookbook/basket-analysis/)). Write 2–3 questions you'd be interested in exploring...this will come in handy as we start thinking about your midterm project!

# %% [markdown]
# ---
#
# ## Wrap-up & Reflection (~3–5 min)
#
# ### What You Practiced
#
# - Structuring Jupyter notebooks with the Problem → Approach → Code → Interpretation pattern
# - Selecting and using lists, tuples, and dictionaries for different business data shapes
# - Importing standard library modules (`datetime`, `random`) and third-party packages (`numpy`, `pandas`, `seaborn`)
# - Combining multiple Python tools to answer realistic, multi-step business questions
#
# ### Reflection
#
# Take 2 minutes individually, then share with your group:
#
# - Which data structure challenge was hardest — and why?
# - When would you reach for a dictionary over a list in your own work?
# - Look back at your Part B cells: could a colleague understand your analysis without asking you a single question? What would make it clearer?
#
# ### Next Steps
#
# - **Chapters:** Review Chapters 4–6 if anything from today needs clarification
# - **Project:** The `completejourney_py` dataset is the foundation of your midterm project — you'll use `transactions`, `products`, and demographic data throughout the course

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# **`IndexError: list index out of range`** — You accessed an index that doesn't exist. Python uses zero-based indexing: a 5-item list has valid indices 0–4, not 1–5.
#
# **`KeyError`** — The dictionary key you tried doesn't exist. Check available keys with `dict.keys()`, or use `dict.get('key', default)` for safe access without an error.
#
# **`TypeError: 'tuple' object does not support item assignment`** — Tuples are immutable. To modify grouped data, use a list or create a new tuple.
#
# **`AttributeError: 'list' object has no attribute '...'`** — You called a NumPy method on a plain Python list. Convert first: `np.array(my_list)`.
#
# **`ModuleNotFoundError`** — The package isn't installed in this environment. Run `!pip install package_name` in a code cell, then re-run the import.
