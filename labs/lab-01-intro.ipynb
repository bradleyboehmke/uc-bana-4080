# %% [markdown]
# # Week 1 Lab: Python Basics
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bradleyboehmke/uc-bana-4080/blob/main/labs/lab-01-intro.ipynb)
#
# Every data analysis starts with Python's basic building blocks. Understanding how data is typed, stored, and compared is what lets you clean, filter, and summarize data reliably in later weeks — and those are exactly the skills that make the rest of BANA 4080 work.
#
# ## Learning Objectives
# By the end of this lab, you will be able to:
# - Use `print()` to display and inspect values during analysis
# - Identify and convert between Python's core data types (`int`, `float`, `str`, `bool`)
# - Store, update, and compute with variables using arithmetic and string operations
# - Write comparison expressions that evaluate to `True` or `False`
#
# ## Lab Structure
# **Total time:** 75 minutes | **Format:** Small groups (2–4 students)
#
# | Segment | Duration |
# |---------|----------|
# | Part A: Guided Reinforcement | ~30 min |
# | Class Q&A & Transition | ~5–10 min |
# | Part B: Independent Challenges | ~35–40 min |
# | Wrap-up & Reflection | ~3–5 min |
#
# ## This Lab Reinforces
# - [**Chapter 2: Preparing for Code**](https://bradleyboehmke.github.io/uc-bana-4080/book/02-preparing-for-code.html)
# - [**Chapter 3: Python Basics**](https://bradleyboehmke.github.io/uc-bana-4080/book/03-python-basics.html)

# %% [markdown]
# ## Try It Before We Start!
#
# Let's run a few lines of Python code before we dive in.

# %%
# Store your name as a string
name = "Taylor"

# Store your age as a number
age = 22

# Print a personalized message
print("Hi " + name + "! You are " + str(age) + " years old.")

# Calculate how many years until you turn 30
years_to_30 = 30 - age
print("You'll turn 30 in " + str(years_to_30) + " years.")

# %% [markdown]
# What just happened?
#
# * You stored information using variables
# * You worked with different data types (a string and a number)
# * You used basic math and printed a personalized message
#
# Don't worry if this isn't totally clear yet — it will be by the end of this lab!

# %% [markdown]
# ---
#
# ## Part A — Guided Reinforcement (~30 min)
#
# Work through the sections below with your TA. Run each code cell, read the explanation, and complete the "Your Turn" exercises as you go.

# %% [markdown]
# ### 1. Revisiting Our First Line of Code
# Let's go back to that first line of Python code you ran in Colab:

# %%
print("Hello, World!")

# %% [markdown]
# Now go ahead and run the following line of code which is similar but doesn't include the `print()` function:

# %%
"Hello, World!"

# %% [markdown]
# Do you notice a difference in the output? How about if you run the following code:

# %%
10 + 5
20 + 3
print(10 + 5)
print(20 + 3)

# %% [markdown]
# #### Discussion
# - What did you notice about the difference between lines with `print()` and those without?
# - How many outputs were shown when you ran the code?

# %% [markdown]
# The `print()` function in Python is a built-in function used to display output to the console or other specified destinations. It takes one or more arguments and converts them to string representations before writing them.

# %%
# We can even combine multiple items in a single print statement:
print("The sum of 10 and 5 is", 10 + 5)

# %% [markdown]
# But we're getting ahead of ourselves! Let's take a step back and look at some of the basic data types in Python and also some basic operations we can do on these data types.

# %% [markdown]
# ### 2. Python Data Types
# Explore the four common types:

# %%
x = 10             # int
y = 3.14           # float
z = "data"         # str
is_student = True  # bool

# %% [markdown]
# We can use the `type()` function to check the type of a variable. Go ahead and run the following code to see the types of the variables we just created:

# %%
type(x)

# %% [markdown]
# #### 🧠 Your Turn
#
# 1. Run `type()` on each variable (`x`, `y`, `z`, `is_student`) to see their types.
# 2. Change `x` to `10.5`, `y` to `"hello"`, `z` to `False`, and `is_student` to `1` and re-run the type checks.
# 3. Before you run the following, what do you think the data types are? Then run to check:
#     ```python
#     print(type("True"))
#     print(type(True))
#     ```

# %%
# Your code here

# %% [markdown]
# ### 3. Variables and Assignment
#
# In the section above, we created variables like `x`, `y`, `z`, and `is_student`. These are just names we give to values so we can refer to them later in our code.
#
# * `x`, `y`, `z`, and `is_student` are variable names.
# * `10`, `3.14`, `"data"`, and `True` are the values assigned to those variables.
# * The `=` operator is used to **assign** a value to a variable.

# %%
price = 2.99
quantity = 4
total = price * quantity
print("Total:", total)

# %% [markdown]
# #### 🧠 Your Turn
# Change the price or quantity values and rerun the calculation.

# %%
# Your code here

# %% [markdown]
# ### 4. Common Operations
#
# In the example above, we did some basic math with our variables. Python allows us to perform various operations on our data types. Here are some common operations.

# %% [markdown]
# #### Numeric Operations
#
# Go ahead and run the following code to see some basic operations with numbers:
#
# ```python
# # Basic operations
# 10 - 3.5   # Subtraction
# 10 * 3.5   # Multiplication
# 10 / 3.5   # Division (always returns a float)
#
# # More math
# 10 ** 3.5  # Exponentiation
# 10 // 3.5  # Integer division
# 10 % 3.5   # Modulus (remainder)
# ```

# %% [markdown]
# #### 🧠 Your Turn — Pizza Value
#
# A 12-inch pizza costs \$8. Use the formula for the area of a circle ($A = \pi \times r^2$) to calculate the **cost per square inch** of the pizza.
#
# Hints:
# * Radius ($r$) is half the diameter
# * Use `3.14159` as your approximation for $\pi$
# * Divide the price by the area to get cost per square inch
#
# Now repeat for a 15-inch pizza that costs \$12. Which is a better deal?

# %%
# Your code here

# %% [markdown]
# #### String Operations
#
# Strings can be combined (concatenated), repeated, or sliced (getting parts of the string).

# %%
# Concatenation
"Hello" + " " + "BANA 4080!"

# %%
# String repetition
"ha" * 3

# %%
# Get first letter (starts at 0)
"Taylor"[0]

# Get first three letters
"Taylor"[:3]

# %% [markdown]
# #### 🧠 Your Turn
#
# 1. First, guess what each line of code will result in. Then run them. Were the results what you expected?
#     ```python
#     print("Python" + "Rocks")
#     print("ha" * 5)
#     print("banana"[1])
#     print("banana"[::-1])
#     ```
# 2. Can you use slicing to print just the word `"ana"` from `"banana"`?

# %%
# Your code here

# %% [markdown]
# ### 5. Comparison Operators
#
# We often need to compare values in our code. Python provides several comparison operators that return `True` or `False` based on the comparison.
#
# | Operator | Description | Example | Result |
# |----------|-------------|---------|--------|
# | `==` | Equal to | `5 == 5` | `True` |
# | `!=` | Not equal to | `5 != 3` | `True` |
# | `>` | Greater than | `10 > 7` | `True` |
# | `<` | Less than | `4 < 2` | `False` |
# | `>=` | Greater than or equal to | `3 >= 3` | `True` |
# | `<=` | Less than or equal to | `8 <= 6` | `False` |

# %%
a = 10
b = 5
print(a > b)
print(a == b)
print("hello" != "world")

# %% [markdown]
# #### 🧠 Your Turn
#
# **Exercise 1 — Stock Price Comparison**
#
# Look up yesterday's closing stock price and today's current price for Kroger (you can make up values if needed). Assign them to variables and write a comparison to see if today's price is higher.
#
# ```python
# kr_close = _____
# kr_current = _____
#
# print("Is today's price higher than yesterday's close?", kr_current ____ kr_close)
# ```
#
# **Exercise 2 — Purchase Quantity Check**
#
# A customer wants to buy 5 items. A promotion applies only if they buy 3 or more. Write a comparison to check if the promotion applies.
#
# **Exercise 3 — Hot Seller Check**
#
# A product is a "hot seller" if its `average_rating` is greater than 4.5 and `num_reviews` is over 100. Use `average_rating = 4.7` and `num_reviews = 135` and print whether it's a hot seller.

# %%
# Your code here

# %% [markdown]
# ### 6. Putting It All Together
#
# A recap combining variables, math, and print formatting.

# %%
# Store your name as a string
name = _________

# Store your age as a number
age = __

# Print a personalized message
print("Hi, my name is " + name + "! I am " + str(age) + " years old.")

# Calculate how many years until you turn 30
years_to_30 = 30 - age
print("I'll turn 30 in " + str(years_to_30) + " years.")

# %% [markdown]
# ---
#
# ## Class Q&A & Transition (~5–10 min)
#
# Take a few minutes to compare your Part A results with another group. Discussion prompts:
# - What surprised you about how Python handles different data types?
# - When would you use `==` versus `=` in a real analysis?
# - What error did you run into (if any) and how did you fix it?

# %% [markdown]
# ---
#
# ## Part B — Independent Challenges (~35–40 min)
#
# For each challenge below:
# - **Start from a blank cell** — no starter code is provided
# - **Do not use AI** to generate code; work with your group to write it from scratch
# - **Ask your instructor** if you're stuck after 3–5 minutes
# - We'll debrief each challenge as a class when time is called

# %% [markdown]
# ### Challenge 1 — Event Revenue Summary
#
# Your student club is hosting a networking event with the following details:
#
# - **Event name:** "Python for Everyone"
# - **Tickets sold:** 56
# - **Ticket price:** $10.50
# - **Revenue goal:** $600
#
# Write code that:
# 1. Assigns each value to a well-named variable
# 2. Calculates total revenue
# 3. Prints a formatted summary showing the event name, tickets sold, ticket price, total revenue, and whether the revenue goal was met
#
# **Hint:** Use `str()` to convert numbers to strings for concatenation, or use a `print()` with comma-separated values.

# %%
# Your code here

# %% [markdown]
# ### Challenge 2 — Product Discount Calculator
#
# A retail analyst needs to calculate discounted prices for three products:
#
# | Product | Original Price | Discount Rate |
# |---------|---------------|---------------|
# | Coffee maker | $89.99 | 15% |
# | Blender | $54.50 | 20% |
# | Toaster | $32.00 | 10% |
#
# Write code that:
# 1. Stores each product's name, original price, and discount rate as variables
# 2. Calculates the discounted price and dollar savings for each product
# 3. Prints a summary identifying which product offers the greatest dollar savings
#
# **Hint:** Dollar savings = original price × discount rate.

# %%
# Your code here

# %% [markdown]
# ### Challenge 3 — Store Performance Check
#
# A regional manager is reviewing three stores' daily sales against their targets:
#
# | Store | Sales | Target |
# |-------|-------|--------|
# | Downtown | $14,200 | $13,500 |
# | Eastside | $9,800 | $11,000 |
# | Westpark | $12,100 | $12,000 |
#
# Write code that:
# 1. Stores each store's name, sales, and target as variables
# 2. Calculates the dollar difference (sales − target) for each store
# 3. Uses comparison operators to print `True` or `False` for whether each store met its target
# 4. Prints which store had the highest sales
#
# **Hint:** Use comparison operators (`>`, `==`, `<`) and `print()` to display results.

# %%
# Your code here

# %% [markdown]
# ### Challenge 4 — Inventory Reorder Alert
#
# A warehouse tracks inventory for a product with these values:
# - **Product name:** "Premium Roast Coffee — 12oz"
# - **Units in stock:** 47
# - **Average units sold per day:** 8
# - **Reorder point:** 30 units
# - **Unit cost:** $6.25
#
# Write code that:
# 1. Stores all values as appropriately typed variables
# 2. Calculates days of inventory remaining (stock ÷ daily sales)
# 3. Calculates total inventory value (units × unit cost)
# 4. Prints whether the stock is currently below the reorder point
# 5. Prints a single summary string that includes the product name, days of inventory remaining, and total inventory value
#
# **Hint:** Combine `str()` conversions and `round()` for clean output.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## (Optional) Extension
#
# If your group finishes early:
#
# ### Extension 1 — f-strings
# Python has a cleaner way to format strings called **f-strings**. Look up the syntax and rewrite your Challenge 1 or Challenge 4 print statements using f-strings instead of concatenation.
#
# ### Extension 2 — Explore
# What other business questions could you answer using only variables, math, and comparison operators? Write 2 questions and attempt one.

# %% [markdown]
# ---
#
# ## Wrap-up & Reflection (~3–5 min)
#
# ### What You Practiced
# - Using `print()` to display and inspect values
# - Identifying and converting between `int`, `float`, `str`, and `bool`
# - Storing and computing with variables
# - Writing arithmetic, string, and comparison expressions
#
# ### Reflection
# Take 2 minutes individually, then share with your group:
# - What was the trickiest part of today's lab?
# - How would variables and comparisons show up in a real data analysis task?
# - What do you still want more practice with?
#
# ### Next Steps
# - **Chapters:** Review Chapters 2–3 if anything from today needs clarification
# - **Project:** The midterm project uses the Complete Journey retail dataset — the types of variables and calculations you practiced today are exactly how you'll start exploring that data in upcoming weeks

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# **`TypeError: can only concatenate str (not "int") to str`**
# Mixing strings and numbers in concatenation. Fix: wrap the number with `str()` → `"value: " + str(42)`
#
# **`NameError: name 'x' is not defined`**
# Using a variable before assigning it, or a typo in the name. Check spelling and make sure the assignment cell ran.
#
# **`SyntaxError` near `=`**
# Using `=` where `==` is needed in a comparison. Remember: `=` assigns a value, `==` compares two values.
#
# **`TypeError: unsupported operand type(s) for *: 'str' and 'int'`**
# Trying to do math on a string variable. Check `type()` of your variable and convert with `int()` or `float()` first.
#
# **General debugging tip:** When you get an error, read the last line of the traceback first — it tells you what went wrong. Then look at the line number to find where.
